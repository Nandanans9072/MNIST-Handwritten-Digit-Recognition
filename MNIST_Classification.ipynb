# %%
# !pip install tensorflow

# %% [markdown]
# ***Importing Libraries***
#
# ---

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Flatten
from tensorflow.keras.utils import to_categorical

# %%
#Load the dataset
(x_train,y_train),(x_test , y_test) = mnist.load_data()

#Normalize the input data
x_train,x_test = x_train /255.0,x_test/255.0

#One-hot encode the labels
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
model=Sequential([
    Flatten(input_shape=(28 ,28)),
    Dense(128,activation='relu'),
    Dense(10,activation='softmax')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(x_train,y_train,epochs=5,validation_data=(x_test,y_test))
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8771 - loss: 0.4339 - val_accuracy: 0.9580 - val_loss: 0.1414
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9632 - loss: 0.1257 - val_accuracy: 0.9676 - val_loss: 0.1061
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9760 - loss: 0.0820 - val_accuracy: 0.9740 - val_loss: 0.0892
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9823 - loss: 0.0585 - val_accuracy: 0.9753 - val_loss: 0.0798
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9870 - loss: 0.0436 - val_accuracy: 0.9778 - val_loss: 0.0757

# %%
test_loss, test_acc=model.evaluate(x_test,y_test)
print('Test accuracy:',test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9734 - loss: 0.0911
# Test accuracy: 0.9778000116348267

# %%
model.save('mnist_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# !apt-get install git -qq

# %%
# !git config --global user.email "nsnandana812@gmail.com"
# !git config --global user.name "Nandana"

# %%
# !git clone https://github.com/Nandanans9072/MNIST-Handwritten-Digit-Recognition.git
# Out:
# Cloning into 'MNIST-Handwritten-Digit-Recognition'...
# ...

# %%
# !cp MNIST_Classification.ipynb MNIST-Handwritten-Digit-Recognition/
# !cp mnist_model.h5 MNIST-Handwritten-Digit-Recognition/   # if saved
# Out:
# cp: cannot stat 'MNIST_Classification.ipynb': No such file or directory
